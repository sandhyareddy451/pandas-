# %%
import pandas as pd

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/vamsikrishnaprasad/predictive-Analytics-for-Retail-Banking/master/bank.csv')

# %%
df
# Out:
#        age          job  marital  education fault  balance housing loan  \
# 0       59       admin.  married  secondary    no     2343     yes   no
# 1       56       admin.  married  secondary    no       45      no   no
# 2       41   technician  married  secondary    no     1270     yes   no
# 3       55     services  married  secondary    no     2476     yes   no
# 4       54       admin.  married   tertiary    no      184      no   no
# ...    ...          ...      ...        ...   ...      ...     ...  ...
# 11157   33  blue-collar   single    primary    no        1     yes   no
# 11158   39     services  married  secondary    no      733      no   no
# 11159   32   technician   single  secondary    no       29      no   no
# 11160   43   technician  married  secondary    no        0      no  yes
# 11161   34   technician  married  secondary    no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [raw]
# 1.how many campaign available in this dataset?
# 2.how many users do we have with housing and personal loan?
# 3.how many persons do we have age is 60+?
# 4. in which month do we have targeted most of the customer?
# 5. which mode of call giving you more result?
# 6.how many enterpeures we do have in this list?
# 7.how many customers do we have with negitive balance?
# 8.prepare a group of data based on education level?

# %% [markdown]
# ## 1. how many campaign available in this dataset?

# %%
len(df["campaign"].unique())
# Out:
# 36

# %% [markdown]
# ### 2. how many users do we have with housing and personal loan?

# %%
df[(df["housing"]=='yes') & (df["loan"]=='yes')]
# Out:
#        age          job   marital  education fault  balance housing loan  \
# 5       42   management    single   tertiary    no        0     yes  yes
# 6       56   management   married   tertiary    no      830     yes  yes
# 12      29   management   married   tertiary    no      199     yes  yes
# 19      49       admin.  divorced  secondary    no      168     yes  yes
# 40      60  blue-collar   married    primary    no     1262     yes  yes
# ...    ...          ...       ...        ...   ...      ...     ...  ...
# 11126   35   unemployed   married  secondary   yes     1054     yes  yes
# 11132   32  blue-collar   married  secondary    no     -325     yes  yes
# 11143   38   unemployed  divorced  secondary    no      189     yes  yes
# 11154   52   technician   married   tertiary    no      523     yes  yes
# 11155   35  blue-collar   married  secondary    no       80     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# ### 3. how many persons do we have age is 60+?

# %%
len(df[df["age"]>60])
# Out:
# 611

# %% [markdown]
# ### 4. in which month do we have targeted most of the customer?

# %%
df["month"].value_counts().max()
# Out:
# 2824

# %% [markdown]
# ### 5. which mode of call giving you more result?

# %%
df["contact"].value_counts().
# Out:
#   Input In [8]
#     df["contact"].value_counts().
#                                  ^
# SyntaxError: invalid syntax

# %%
df1=df.groupby(["contact","deposit"]).count()

# %%
df1
# Out:
#                     age   job  marital  education  fault  balance  housing  \
# contact   deposit
# cellular  no       3673  3673     3673       3673   3673     3673     3673
#           yes      4369  4369     4369       4369   4369     4369     4369
# telephone no        384   384      384        384    384      384      384
#           yes       390   390      390        390    390      390      390
# unknown   no       1816  1816     1816       1816   1816     1816     1816
#           yes       530   530      530        530    530      530      530
#
#                    loan   day  month  duration  campaign  pdays  previous  \
# contact   deposit
# cellular  no       3673  3673   3673      3673      3673   3673      3673
#           yes      4369  4369   4369      4369      4369   4369      4369
# telephone no        384   384    384       384       384    384       384
#           yes       390   390    390       390       390    390       390
# ...

# %% [markdown]
# ### 6. how many enterpeures we do have in this list?

# %%
len(df[df["job"]=='entrepreneur'])
# Out:
# 328

# %% [markdown]
# ### 7.how many customers do we have with negitive balance?

# %%
df
# Out:
#        age          job  marital  education fault  balance housing loan  \
# 0       59       admin.  married  secondary    no     2343     yes   no
# 1       56       admin.  married  secondary    no       45      no   no
# 2       41   technician  married  secondary    no     1270     yes   no
# 3       55     services  married  secondary    no     2476     yes   no
# 4       54       admin.  married   tertiary    no      184      no   no
# ...    ...          ...      ...        ...   ...      ...     ...  ...
# 11157   33  blue-collar   single    primary    no        1     yes   no
# 11158   39     services  married  secondary    no      733      no   no
# 11159   32   technician   single  secondary    no       29      no   no
# 11160   43   technician  married  secondary    no        0      no  yes
# 11161   34   technician  married  secondary    no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df[df["balance"]<0]
# Out:
#        age           job   marital  education fault  balance housing loan  \
# 17      49      services   married  secondary    no       -8     yes   no
# 23      43   blue-collar   married    primary    no     -192     yes   no
# 30      32   blue-collar   married  secondary   yes       -1     yes   no
# 42      45  entrepreneur  divorced   tertiary    no     -395     yes   no
# 59      57    technician   married   tertiary    no       -1      no   no
# ...    ...           ...       ...        ...   ...      ...     ...  ...
# 11119   39    management   married   tertiary    no     -974      no  yes
# 11120   50    management   married   tertiary    no     -516     yes   no
# 11132   32   blue-collar   married  secondary    no     -325     yes  yes
# 11145   60       retired  divorced   tertiary    no     -134      no   no
# 11156   34   blue-collar    single  secondary    no      -72     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# ### 8. prepare a group of data based on education level?

# %%
df["education"].value_counts()
# Out:
# secondary    5476
# tertiary     3689
# primary      1500
# unknown       497
# Name: education, dtype: int64

# %%
l=[]
for i in df["education"].unique():
    l.append(df[df["education"]==i])

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#        age          job   marital  education fault  balance housing loan  \
# 0       59       admin.   married  secondary    no     2343     yes   no
# 1       56       admin.   married  secondary    no       45      no   no
# 2       41   technician   married  secondary    no     1270     yes   no
# 3       55     services   married  secondary    no     2476     yes   no
# 7       60      retired  divorced  secondary    no      545     yes   no
# ...    ...          ...       ...        ...   ...      ...     ...  ...
# 11156   34  blue-collar    single  secondary    no      -72     yes   no
# 11158   39     services   married  secondary    no      733      no   no
# 11159   32   technician    single  secondary    no       29      no   no
# 11160   43   technician   married  secondary    no        0      no  yes
# 11161   34   technician   married  secondary    no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
l[1]
# Out:
#        age            job   marital education fault  balance housing loan  \
# 4       54         admin.   married  tertiary    no      184      no   no
# 5       42     management    single  tertiary    no        0     yes  yes
# 6       56     management   married  tertiary    no      830     yes  yes
# 12      29     management   married  tertiary    no      199     yes  yes
# 13      46    blue-collar    single  tertiary    no      460     yes   no
# ...    ...            ...       ...       ...   ...      ...     ...  ...
# 11136   31     management    single  tertiary    no        0     yes   no
# 11139   30  self-employed    single  tertiary    no     2593      no   no
# 11145   60        retired  divorced  tertiary    no     -134      no   no
# 11151   40     management   married  tertiary    no      917     yes   no
# 11154   52     technician   married  tertiary    no      523     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
l[2]
# Out:
#        age          job   marital education fault  balance housing loan  \
# 16      32  blue-collar    single   primary    no      611     yes   no
# 23      43  blue-collar   married   primary    no     -192     yes   no
# 31      60   technician   married   primary    no       65     yes   no
# 34      33  blue-collar  divorced   primary    no      390     yes   no
# 36      35  blue-collar   married   primary    no      414      no   no
# ...    ...          ...       ...       ...   ...      ...     ...  ...
# 11115   49  blue-collar   married   primary    no       67      no  yes
# 11124   42      retired   married   primary    no        0     yes   no
# 11125   40  blue-collar  divorced   primary    no       54     yes   no
# 11128   40  blue-collar   married   primary    no     2171     yes   no
# 11157   33  blue-collar    single   primary    no        1     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
l[3]
# Out:
#        age          job  marital education fault  balance housing loan  \
# 44      52   management  married   unknown    no     2240     yes   no
# 58      40   technician   single   unknown    no     3652     yes   no
# 65      44  blue-collar  married   unknown    no      146     yes   no
# 75      36     services   single   unknown    no      281     yes   no
# 108     35  blue-collar  married   unknown    no     4822     yes   no
# ...    ...          ...      ...       ...   ...      ...     ...  ...
# 11017   42  blue-collar  married   unknown    no     1154     yes   no
# 11038   36  blue-collar  married   unknown    no     1023     yes   no
# 11059   35   technician   single   unknown    no      726     yes   no
# 11072   41   technician   single   unknown    no      356     yes   no
# 11137   49      retired  married   unknown    no      247      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...
